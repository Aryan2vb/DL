# %% [markdown]
# # **Notebook 11.2: Residual Networks - Solution**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/nl/dlkpwjz166lclq72mwpm8nlm0000gn/T/pip-req-build-gu31se_y
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/nl/dlkpwjz166lclq72mwpm8nlm0000gn/T/pip-req-build-gu31se_y
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/ru/Library/Python/3.9/lib/python/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /Users/ru/Library/Python/3.9/lib/python/site-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /Users/ru/Library/Python/3.9/lib/python/site-packages (from mnist1d==0.0.2.post16) (3.9.4)
# Requirement already satisfied: scipy in /Users/ru/Library/Python/3.9/lib/python/site-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from matplotlib->mnist1d==0.0.2.post16) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ru/Library/Python/3.9/lib/python/site-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random
# Out:
# /Users/ru/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
  def forward(self, x):
    h1 = self.linear1(x)
    # Residual connection: input + f(input)
    # First residual block
    h2 = h1 + self.linear2(h1.relu())
    # Second residual block
    h3 = h2 + self.linear3(h2.relu())
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.537793, train error 58.60,  val loss 1.638148, percent error 65.50
# Epoch     1, train loss 1.259778, train error 46.67,  val loss 1.458053, percent error 57.80
# Epoch     2, train loss 1.067160, train error 39.60,  val loss 1.341594, percent error 52.90
# Epoch     3, train loss 0.916886, train error 33.75,  val loss 1.275627, percent error 50.10
# Epoch     4, train loss 0.770625, train error 27.82,  val loss 1.201933, percent error 46.40
# Epoch     5, train loss 0.662650, train error 24.18,  val loss 1.198294, percent error 43.90
# Epoch     6, train loss 0.560842, train error 20.32,  val loss 1.175455, percent error 42.00
# Epoch     7, train loss 0.491712, train error 16.88,  val loss 1.160127, percent error 42.60
# Epoch     8, train loss 0.397017, train error 13.28,  val loss 1.139331, percent error 40.70
# Epoch     9, train loss 0.399118, train error 13.88,  val loss 1.334435, percent error 40.60
# Epoch    10, train loss 0.291818, train error 9.68,  val loss 1.203141, percent error 37.90
# Epoch    11, train loss 0.278043, train error 9.32,  val loss 1.381741, percent error 40.60
# Epoch    12, train loss 0.231185, train error 7.50,  val loss 1.382452, percent error 38.60
# Epoch    13, train loss 0.180472, train error 5.25,  val loss 1.402287, percent error 37.60
# Epoch    14, train loss 0.169833, train error 5.30,  val loss 1.408975, percent error 36.50
# Epoch    15, train loss 0.134853, train error 4.43,  val loss 1.493641, percent error 37.90
# Epoch    16, train loss 0.112317, train error 2.80,  val loss 1.550556, percent error 36.40
# Epoch    17, train loss 0.077681, train error 2.07,  val loss 1.649584, percent error 36.20
# Epoch    18, train loss 0.082077, train error 1.78,  val loss 1.647542, percent error 36.80
# Epoch    19, train loss 0.051932, train error 1.07,  val loss 1.665463, percent error 36.30
# Epoch    20, train loss 0.019578, train error 0.05,  val loss 1.604100, percent error 33.40
# Epoch    21, train loss 0.011840, train error 0.00,  val loss 1.643588, percent error 33.80
# Epoch    22, train loss 0.009049, train error 0.00,  val loss 1.657938, percent error 34.20
# Epoch    23, train loss 0.007844, train error 0.00,  val loss 1.680005, percent error 34.40
# Epoch    24, train loss 0.007058, train error 0.00,  val loss 1.697753, percent error 34.30
# Epoch    25, train loss 0.006456, train error 0.00,  val loss 1.715225, percent error 34.30
# Epoch    26, train loss 0.006005, train error 0.00,  val loss 1.733228, percent error 33.90
# Epoch    27, train loss 0.005560, train error 0.00,  val loss 1.746084, percent error 33.90
# Epoch    28, train loss 0.005210, train error 0.00,  val loss 1.760262, percent error 34.10
# Epoch    29, train loss 0.004918, train error 0.00,  val loss 1.773959, percent error 34.00
# Epoch    30, train loss 0.004650, train error 0.00,  val loss 1.785846, percent error 34.20
# Epoch    31, train loss 0.004408, train error 0.00,  val loss 1.798967, percent error 34.30
# Epoch    32, train loss 0.004195, train error 0.00,  val loss 1.807654, percent error 34.20
# Epoch    33, train loss 0.004003, train error 0.00,  val loss 1.820490, percent error 33.90
# Epoch    34, train loss 0.003829, train error 0.00,  val loss 1.831341, percent error 34.00
# Epoch    35, train loss 0.003666, train error 0.00,  val loss 1.841162, percent error 34.10
# Epoch    36, train loss 0.003522, train error 0.00,  val loss 1.850877, percent error 34.10
# Epoch    37, train loss 0.003391, train error 0.00,  val loss 1.858186, percent error 34.00
# Epoch    38, train loss 0.003259, train error 0.00,  val loss 1.865669, percent error 34.20
# Epoch    39, train loss 0.003145, train error 0.00,  val loss 1.875630, percent error 34.50
# Epoch    40, train loss 0.003087, train error 0.00,  val loss 1.880112, percent error 34.60
# Epoch    41, train loss 0.003034, train error 0.00,  val loss 1.884046, percent error 34.40
# Epoch    42, train loss 0.002983, train error 0.00,  val loss 1.888502, percent error 34.50
# Epoch    43, train loss 0.002934, train error 0.00,  val loss 1.892462, percent error 34.40
# Epoch    44, train loss 0.002888, train error 0.00,  val loss 1.895922, percent error 34.60
# Epoch    45, train loss 0.002842, train error 0.00,  val loss 1.899546, percent error 34.60
# Epoch    46, train loss 0.002798, train error 0.00,  val loss 1.903554, percent error 34.60
# Epoch    47, train loss 0.002756, train error 0.00,  val loss 1.906776, percent error 34.60
# Epoch    48, train loss 0.002714, train error 0.00,  val loss 1.910761, percent error 34.40
# Epoch    49, train loss 0.002674, train error 0.00,  val loss 1.914026, percent error 34.50
# Epoch    50, train loss 0.002634, train error 0.00,  val loss 1.917403, percent error 34.60
# Epoch    51, train loss 0.002597, train error 0.00,  val loss 1.921066, percent error 34.60
# Epoch    52, train loss 0.002560, train error 0.00,  val loss 1.924284, percent error 34.60
# Epoch    53, train loss 0.002524, train error 0.00,  val loss 1.927764, percent error 34.50
# Epoch    54, train loss 0.002490, train error 0.00,  val loss 1.931604, percent error 34.50
# Epoch    55, train loss 0.002455, train error 0.00,  val loss 1.934896, percent error 34.60
# Epoch    56, train loss 0.002422, train error 0.00,  val loss 1.937582, percent error 34.60
# Epoch    57, train loss 0.002391, train error 0.00,  val loss 1.940454, percent error 34.60
# Epoch    58, train loss 0.002359, train error 0.00,  val loss 1.943861, percent error 34.50
# Epoch    59, train loss 0.002329, train error 0.00,  val loss 1.946466, percent error 34.60
# Epoch    60, train loss 0.002313, train error 0.00,  val loss 1.947856, percent error 34.50
# Epoch    61, train loss 0.002298, train error 0.00,  val loss 1.949771, percent error 34.50
# Epoch    62, train loss 0.002284, train error 0.00,  val loss 1.951282, percent error 34.50
# Epoch    63, train loss 0.002269, train error 0.00,  val loss 1.952453, percent error 34.50
# Epoch    64, train loss 0.002255, train error 0.00,  val loss 1.954041, percent error 34.40
# Epoch    65, train loss 0.002241, train error 0.00,  val loss 1.955277, percent error 34.40
# Epoch    66, train loss 0.002227, train error 0.00,  val loss 1.957096, percent error 34.40
# Epoch    67, train loss 0.002214, train error 0.00,  val loss 1.958690, percent error 34.40
# Epoch    68, train loss 0.002200, train error 0.00,  val loss 1.959885, percent error 34.40
# Epoch    69, train loss 0.002187, train error 0.00,  val loss 1.961051, percent error 34.50
# Epoch    70, train loss 0.002174, train error 0.00,  val loss 1.962741, percent error 34.40
# Epoch    71, train loss 0.002161, train error 0.00,  val loss 1.964236, percent error 34.50
# Epoch    72, train loss 0.002148, train error 0.00,  val loss 1.965988, percent error 34.50
# Epoch    73, train loss 0.002135, train error 0.00,  val loss 1.967348, percent error 34.50
# Epoch    74, train loss 0.002122, train error 0.00,  val loss 1.968270, percent error 34.50
# Epoch    75, train loss 0.002110, train error 0.00,  val loss 1.969756, percent error 34.50
# Epoch    76, train loss 0.002098, train error 0.00,  val loss 1.971113, percent error 34.50
# Epoch    77, train loss 0.002085, train error 0.00,  val loss 1.972675, percent error 34.50
# Epoch    78, train loss 0.002074, train error 0.00,  val loss 1.973916, percent error 34.50
# Epoch    79, train loss 0.002061, train error 0.00,  val loss 1.975405, percent error 34.50
# Epoch    80, train loss 0.002055, train error 0.00,  val loss 1.976028, percent error 34.50
# Epoch    81, train loss 0.002050, train error 0.00,  val loss 1.976805, percent error 34.50
# Epoch    82, train loss 0.002044, train error 0.00,  val loss 1.977244, percent error 34.50
# Epoch    83, train loss 0.002038, train error 0.00,  val loss 1.978060, percent error 34.50
# Epoch    84, train loss 0.002032, train error 0.00,  val loss 1.978616, percent error 34.50
# Epoch    85, train loss 0.002026, train error 0.00,  val loss 1.979294, percent error 34.50
# Epoch    86, train loss 0.002021, train error 0.00,  val loss 1.980077, percent error 34.50
# Epoch    87, train loss 0.002015, train error 0.00,  val loss 1.980782, percent error 34.50
# Epoch    88, train loss 0.002009, train error 0.00,  val loss 1.981274, percent error 34.50
# Epoch    89, train loss 0.002004, train error 0.00,  val loss 1.981990, percent error 34.50
# Epoch    90, train loss 0.001998, train error 0.00,  val loss 1.982765, percent error 34.50
# Epoch    91, train loss 0.001992, train error 0.00,  val loss 1.983400, percent error 34.50
# Epoch    92, train loss 0.001987, train error 0.00,  val loss 1.983818, percent error 34.50
# Epoch    93, train loss 0.001981, train error 0.00,  val loss 1.984725, percent error 34.50
# Epoch    94, train loss 0.001976, train error 0.00,  val loss 1.985289, percent error 34.50
# Epoch    95, train loss 0.001970, train error 0.00,  val loss 1.985822, percent error 34.50
# Epoch    96, train loss 0.001965, train error 0.00,  val loss 1.986504, percent error 34.50
# Epoch    97, train loss 0.001960, train error 0.00,  val loss 1.987299, percent error 34.50
# Epoch    98, train loss 0.001954, train error 0.00,  val loss 1.987836, percent error 34.50
# Epoch    99, train loss 0.001949, train error 0.00,  val loss 1.988587, percent error 34.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
#
# For this relatively shallow network (3 hidden layers), the difference might not be dramatic. However, residual connections generally make optimization smoother and more robust, especially as depth increases. In some cases, it can prevent the performance degradation observed in very deep non-residual networks.
