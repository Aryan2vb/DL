# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan2vb/DL/blob/main/cnn-lab/%5Bext%5D10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-rhailxqk
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-rhailxqk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(in_features=60, out_features=10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.192177, train error 83.28,  val loss 2.196955, percent error 84.00
# Epoch     1, train loss 1.630576, train error 62.40,  val loss 1.643618, percent error 65.70
# Epoch     2, train loss 1.410172, train error 56.67,  val loss 1.420693, percent error 57.60
# Epoch     3, train loss 1.263997, train error 49.78,  val loss 1.263071, percent error 52.00
# Epoch     4, train loss 1.253644, train error 51.47,  val loss 1.256814, percent error 53.40
# Epoch     5, train loss 1.117676, train error 45.33,  val loss 1.136275, percent error 46.20
# Epoch     6, train loss 0.983859, train error 37.53,  val loss 1.003304, percent error 41.60
# Epoch     7, train loss 0.854395, train error 33.53,  val loss 0.891181, percent error 34.10
# Epoch     8, train loss 0.724845, train error 28.95,  val loss 0.799509, percent error 33.30
# Epoch     9, train loss 0.700000, train error 27.43,  val loss 0.768216, percent error 29.20
# Epoch    10, train loss 0.591036, train error 22.55,  val loss 0.699391, percent error 26.90
# Epoch    11, train loss 0.536768, train error 21.10,  val loss 0.650888, percent error 27.10
# Epoch    12, train loss 0.450448, train error 16.47,  val loss 0.565931, percent error 19.20
# Epoch    13, train loss 0.473428, train error 17.38,  val loss 0.629575, percent error 22.20
# Epoch    14, train loss 0.445637, train error 16.47,  val loss 0.587281, percent error 22.00
# Epoch    15, train loss 0.348198, train error 12.82,  val loss 0.515786, percent error 19.00
# Epoch    16, train loss 0.292145, train error 10.90,  val loss 0.456583, percent error 16.20
# Epoch    17, train loss 0.366195, train error 13.05,  val loss 0.542864, percent error 18.10
# Epoch    18, train loss 0.299896, train error 10.85,  val loss 0.464085, percent error 15.20
# Epoch    19, train loss 0.218388, train error 7.65,  val loss 0.404777, percent error 15.60
# Epoch    20, train loss 0.161709, train error 5.55,  val loss 0.330439, percent error 11.30
# Epoch    21, train loss 0.155780, train error 5.22,  val loss 0.340425, percent error 12.10
# Epoch    22, train loss 0.157288, train error 5.62,  val loss 0.355148, percent error 12.00
# Epoch    23, train loss 0.144848, train error 5.07,  val loss 0.348645, percent error 11.60
# Epoch    24, train loss 0.124609, train error 4.22,  val loss 0.329489, percent error 10.40
# Epoch    25, train loss 0.113615, train error 3.80,  val loss 0.334794, percent error 11.20
# Epoch    26, train loss 0.149065, train error 5.38,  val loss 0.368733, percent error 12.40
# Epoch    27, train loss 0.162993, train error 5.28,  val loss 0.390238, percent error 12.80
# Epoch    28, train loss 0.109796, train error 3.68,  val loss 0.351674, percent error 11.40
# Epoch    29, train loss 0.087866, train error 2.72,  val loss 0.322794, percent error 10.50
# Epoch    30, train loss 0.081598, train error 2.22,  val loss 0.317872, percent error 10.40
# Epoch    31, train loss 0.092860, train error 3.07,  val loss 0.317093, percent error 10.70
# Epoch    32, train loss 0.081671, train error 2.45,  val loss 0.327107, percent error 10.50
# Epoch    33, train loss 0.091380, train error 3.00,  val loss 0.355741, percent error 11.20
# Epoch    34, train loss 0.086311, train error 2.75,  val loss 0.369675, percent error 11.40
# Epoch    35, train loss 0.079386, train error 2.40,  val loss 0.331325, percent error 11.20
# Epoch    36, train loss 0.059729, train error 1.45,  val loss 0.340469, percent error 10.60
# Epoch    37, train loss 0.068581, train error 2.15,  val loss 0.336120, percent error 10.50
# Epoch    38, train loss 0.060728, train error 1.75,  val loss 0.360270, percent error 10.80
# Epoch    39, train loss 0.074265, train error 2.57,  val loss 0.376143, percent error 11.80
# Epoch    40, train loss 0.046816, train error 0.95,  val loss 0.336653, percent error 9.60
# Epoch    41, train loss 0.044783, train error 0.93,  val loss 0.332105, percent error 10.20
# Epoch    42, train loss 0.046665, train error 1.03,  val loss 0.342221, percent error 10.10
# Epoch    43, train loss 0.044063, train error 1.03,  val loss 0.348092, percent error 10.00
# Epoch    44, train loss 0.043517, train error 0.90,  val loss 0.349982, percent error 10.50
# Epoch    45, train loss 0.041114, train error 0.72,  val loss 0.346570, percent error 10.20
# Epoch    46, train loss 0.040056, train error 0.78,  val loss 0.353937, percent error 9.60
# Epoch    47, train loss 0.036431, train error 0.65,  val loss 0.355308, percent error 9.60
# Epoch    48, train loss 0.040975, train error 0.85,  val loss 0.361778, percent error 9.90
# Epoch    49, train loss 0.037044, train error 0.60,  val loss 0.365899, percent error 9.80
# Epoch    50, train loss 0.034813, train error 0.43,  val loss 0.361302, percent error 9.50
# Epoch    51, train loss 0.034280, train error 0.57,  val loss 0.374048, percent error 10.20
# Epoch    52, train loss 0.033818, train error 0.55,  val loss 0.371690, percent error 9.90
# Epoch    53, train loss 0.031593, train error 0.43,  val loss 0.364571, percent error 9.80
# Epoch    54, train loss 0.031278, train error 0.50,  val loss 0.375617, percent error 10.20
# Epoch    55, train loss 0.031097, train error 0.35,  val loss 0.382178, percent error 9.90
# Epoch    56, train loss 0.029836, train error 0.30,  val loss 0.376723, percent error 10.00
# Epoch    57, train loss 0.028413, train error 0.25,  val loss 0.384517, percent error 9.80
# Epoch    58, train loss 0.030925, train error 0.32,  val loss 0.394762, percent error 9.60
# Epoch    59, train loss 0.028094, train error 0.28,  val loss 0.375195, percent error 10.50
# Epoch    60, train loss 0.026157, train error 0.18,  val loss 0.387072, percent error 10.00
# Epoch    61, train loss 0.025449, train error 0.18,  val loss 0.389436, percent error 10.00
# Epoch    62, train loss 0.025897, train error 0.22,  val loss 0.393765, percent error 10.00
# Epoch    63, train loss 0.024391, train error 0.15,  val loss 0.394688, percent error 10.00
# Epoch    64, train loss 0.024917, train error 0.22,  val loss 0.398558, percent error 9.90
# Epoch    65, train loss 0.024580, train error 0.18,  val loss 0.397414, percent error 10.00
# Epoch    66, train loss 0.023555, train error 0.15,  val loss 0.397785, percent error 10.00
# Epoch    67, train loss 0.023531, train error 0.18,  val loss 0.397417, percent error 10.30
# Epoch    68, train loss 0.023288, train error 0.15,  val loss 0.400848, percent error 10.10
# Epoch    69, train loss 0.023290, train error 0.18,  val loss 0.399794, percent error 10.00
# Epoch    70, train loss 0.022729, train error 0.18,  val loss 0.402062, percent error 10.30
# Epoch    71, train loss 0.022650, train error 0.15,  val loss 0.403527, percent error 10.20
# Epoch    72, train loss 0.022220, train error 0.15,  val loss 0.401184, percent error 10.30
# Epoch    73, train loss 0.021823, train error 0.15,  val loss 0.405427, percent error 10.10
# Epoch    74, train loss 0.022096, train error 0.15,  val loss 0.407140, percent error 9.90
# Epoch    75, train loss 0.021343, train error 0.15,  val loss 0.412275, percent error 10.10
# Epoch    76, train loss 0.021259, train error 0.15,  val loss 0.409074, percent error 10.00
# Epoch    77, train loss 0.021144, train error 0.15,  val loss 0.413822, percent error 10.10
# Epoch    78, train loss 0.022572, train error 0.28,  val loss 0.412637, percent error 10.30
# Epoch    79, train loss 0.021568, train error 0.12,  val loss 0.412640, percent error 10.00
# Epoch    80, train loss 0.020273, train error 0.15,  val loss 0.414781, percent error 9.90
# Epoch    81, train loss 0.020075, train error 0.15,  val loss 0.415024, percent error 9.90
# Epoch    82, train loss 0.019982, train error 0.18,  val loss 0.415888, percent error 10.00
# Epoch    83, train loss 0.019742, train error 0.15,  val loss 0.415981, percent error 10.00
# Epoch    84, train loss 0.019712, train error 0.12,  val loss 0.416847, percent error 10.00
# Epoch    85, train loss 0.019547, train error 0.15,  val loss 0.416627, percent error 9.90
# Epoch    86, train loss 0.019546, train error 0.12,  val loss 0.418797, percent error 10.10
# Epoch    87, train loss 0.019387, train error 0.12,  val loss 0.419440, percent error 10.10
# Epoch    88, train loss 0.019214, train error 0.12,  val loss 0.418669, percent error 9.90
# Epoch    89, train loss 0.019642, train error 0.15,  val loss 0.419946, percent error 10.10
# Epoch    90, train loss 0.019181, train error 0.12,  val loss 0.420880, percent error 9.90
# Epoch    91, train loss 0.018950, train error 0.12,  val loss 0.421048, percent error 9.90
# Epoch    92, train loss 0.018907, train error 0.12,  val loss 0.421492, percent error 10.00
# Epoch    93, train loss 0.018702, train error 0.12,  val loss 0.421789, percent error 9.80
# Epoch    94, train loss 0.018630, train error 0.12,  val loss 0.420965, percent error 9.70
# Epoch    95, train loss 0.018496, train error 0.12,  val loss 0.421899, percent error 9.80
# Epoch    96, train loss 0.018497, train error 0.12,  val loss 0.424080, percent error 9.80
# Epoch    97, train loss 0.018292, train error 0.12,  val loss 0.423836, percent error 9.90
# Epoch    98, train loss 0.018244, train error 0.12,  val loss 0.423832, percent error 9.90
# Epoch    99, train loss 0.018119, train error 0.12,  val loss 0.425758, percent error 9.90
